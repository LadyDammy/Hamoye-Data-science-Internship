# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('energydata_complete.csv')

# %%
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
column_names = {'T1':'Temp in Kitchen', 'RH_1':'Hum in kitchen', 'T2':'Temp in living room', 'RH_2':'Hum in living room', 'T3':'Temp in laund. area', 'RH_3':'Hum in laund. area', 'T4':'Temp in office room','RH_4':'Hum in office room', 'T5':'Temp in bathroom','RH_5':'Hum in bathroom', 'T6':'Temp outside the building','RH_6':'Hum outside the building', 'T7':'Temp in ironing room','RH_7':'Hum in ironing room', 'T8':'Temp in teen room','RH_8':'Hum in teen room', 'T9':'Temp in parent room','RH_9': 'Hum in parent room', 'T_out':'Temp outside(Chievres WS)','RH_out':'Hum outside(Chievres WS)', 'rv1':'Random Variable 1','rv2':'Random variable 2'}
df = df.rename(columns=column_names)

# %%
df
# Out:
#                       date  Appliances  lights  Temp in Kitchen  \
# 0      2016-01-11 17:00:00          60      30        19.890000
# 1      2016-01-11 17:10:00          60      30        19.890000
# 2      2016-01-11 17:20:00          50      30        19.890000
# 3      2016-01-11 17:30:00          50      40        19.890000
# 4      2016-01-11 17:40:00          60      40        19.890000
# ...                    ...         ...     ...              ...
# 19730  2016-05-27 17:20:00         100       0        25.566667
# 19731  2016-05-27 17:30:00          90       0        25.500000
# 19732  2016-05-27 17:40:00         270      10        25.500000
# 19733  2016-05-27 17:50:00         420      10        25.500000
# 19734  2016-05-27 18:00:00         430      10        25.500000
#
#        Hum in kitchen  Temp in living room  Hum in living room  \
# 0           47.596667            19.200000           44.790000
# 1           46.693333            19.200000           44.722500
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
features_df = normalised_df.drop(columns=['Appliances'])
Target = normalised_df['Appliances']

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'Temp in Kitchen', 'Hum in kitchen',
#        'Temp in living room', 'Hum in living room', 'Temp in laund. area',
#        'Hum in laund. area', 'Temp in office room', 'Hum in office room',
#        'Temp in bathroom', 'Hum in bathroom', 'Temp outside the building',
#        'Hum outside the building', 'Temp in ironing room',
#        'Hum in ironing room', 'Temp in teen room', 'Hum in teen room',
#        'Temp in parent room', 'Hum in parent room',
#        'Temp outside(Chievres WS)', 'Press_mm_hg', 'Hum outside(Chievres WS)',
#        'Windspeed', 'Visibility', 'Tdewpoint', 'Random Variable 1',
#        'Random variable 2'],
#       dtype='object')

# %%
df[:]
# Out:
#                       date  Appliances  lights  Temp in Kitchen  \
# 0      2016-01-11 17:00:00          60      30        19.890000
# 1      2016-01-11 17:10:00          60      30        19.890000
# 2      2016-01-11 17:20:00          50      30        19.890000
# 3      2016-01-11 17:30:00          50      40        19.890000
# 4      2016-01-11 17:40:00          60      40        19.890000
# ...                    ...         ...     ...              ...
# 19730  2016-05-27 17:20:00         100       0        25.566667
# 19731  2016-05-27 17:30:00          90       0        25.500000
# 19732  2016-05-27 17:40:00         270      10        25.500000
# 19733  2016-05-27 17:50:00         420      10        25.500000
# 19734  2016-05-27 18:00:00         430      10        25.500000
#
#        Hum in kitchen  Temp in living room  Hum in living room  \
# 0           47.596667            19.200000           44.790000
# 1           46.693333            19.200000           44.722500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       19735 non-null  object
#  1   Appliances                 19735 non-null  int64
#  2   lights                     19735 non-null  int64
#  3   Temp in Kitchen            19735 non-null  float64
#  4   Hum in kitchen             19735 non-null  float64
#  5   Temp in living room        19735 non-null  float64
#  6   Hum in living room         19735 non-null  float64
#  7   Temp in laund. area        19735 non-null  float64
#  8   Hum in laund. area         19735 non-null  float64
#  9   Temp in office room        19735 non-null  float64
#  10  Hum in office room         19735 non-null  float64
#  11  Temp in bathroom           19735 non-null  float64
#  12  Hum in bathroom            19735 non-null  float64
# ...

# %%
df = df.drop(columns=['lights'])

# %%
df
# Out:
#        Appliances  Temp in Kitchen  Hum in kitchen  Temp in living room  \
# 0              60        19.890000       47.596667            19.200000
# 1              60        19.890000       46.693333            19.200000
# 2              50        19.890000       46.300000            19.200000
# 3              50        19.890000       46.066667            19.200000
# 4              60        19.890000       46.333333            19.200000
# ...           ...              ...             ...                  ...
# 19730         100        25.566667       46.560000            25.890000
# 19731          90        25.500000       46.500000            25.754000
# 19732         270        25.500000       46.596667            25.628571
# 19733         420        25.500000       46.990000            25.414000
# 19734         430        25.500000       46.600000            25.264286
#
#        Hum in living room  Temp in laund. area  Hum in laund. area  \
# ...

# %%
df
# Out:
#        Appliances  lights  Temp in Kitchen  Hum in kitchen  \
# 0              60      30        19.890000       47.596667
# 1              60      30        19.890000       46.693333
# 2              50      30        19.890000       46.300000
# 3              50      40        19.890000       46.066667
# 4              60      40        19.890000       46.333333
# ...           ...     ...              ...             ...
# 19730         100       0        25.566667       46.560000
# 19731          90       0        25.500000       46.500000
# 19732         270      10        25.500000       46.596667
# 19733         420      10        25.500000       46.990000
# 19734         430      10        25.500000       46.600000
#
#        Temp in living room  Hum in living room  Temp in laund. area  \
# 0                19.200000           44.790000            19.790000
# 1                19.200000           44.722500            19.790000
# ...

# %%
df.columns
df.iloc[:, 0]
# Out:
# 0         60
# 1         60
# 2         50
# 3         50
# 4         60
#         ...
# 19730    100
# 19731     90
# 19732    270
# 19733    420
# 19734    430
# Name: Appliances, Length: 19735, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train, x_test, y_train, y_test = train_test_split(features_df, Target, test_size=0.3, random_state = 42)
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
predicted_values = linear_model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(y_test, predicted_values)
round(MAE, 2)
# Out:
# 0.05

# %%
from sklearn.metrics import mean_squared_error
RMSE = np.sqrt(mean_squared_error(y_test, predicted_values))
round(RMSE, 3)
# Out:
# 0.088

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score,2)
# Out:
# 0.15

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
def get_weights_df(model, feat, col_name):
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['features', col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')

# %%
final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='features')

# %%
final_weights
# Out:
#                      features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0          Hum in living room            -0.456698     -0.411071     -0.000000
# 1   Temp outside(Chievres WS)            -0.321860     -0.262172      0.000000
# 2         Temp in living room            -0.236178     -0.201397      0.000000
# 3         Temp in parent room            -0.189941     -0.188916     -0.000000
# 4            Hum in teen room            -0.157595     -0.156830     -0.000110
# 5    Hum outside(Chievres WS)            -0.077671     -0.054724     -0.049557
# 6         Hum in ironing room            -0.044614     -0.045977     -0.000000
# 7          Hum in parent room            -0.039800     -0.041367     -0.000000
# 8            Temp in bathroom            -0.015657     -0.019853     -0.000000
# 9             Temp in Kitchen            -0.003281     -0.018406      0.000000
# 10          Random Variable 1             0.000770      0.000748     -0.000000
# ...
