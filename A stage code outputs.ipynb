# %%
import pandas as pd

# %%
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin-1')

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.groupby(['Item']).sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
f= df.groupby(['Element', 'Area']).sum()
f
# Out:
#                                                 Area Code  Item Code  \
# Element                  Area
# Domestic supply quantity Algeria                      464     311204
#                          Angola                       826     316106
#                          Benin                       6148     310985
#                          Botswana                    2340     313766
#                          Burkina Faso               27494     316106
# ...                                                   ...        ...
# Tourist consumption      Cabo Verde                  3150     241236
#                          Egypt                       5546     251428
#                          Kenya                      11172     261986
#                          Mauritius                  12467     243857
#                          Sao Tome and Principe      16019     223107
#
#                                                 Element Code     Y2014  \
# Element                  Area
# ...

# %%
df.groupby(['Element'])

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
  df.groupby(['Area', 'Y2017']).sum()
# Out:
#                    Area Code  Item Code  Element Code    Y2014    Y2015  \
# Area     Y2017
# Algeria  -81.0             8       5536         10144     60.0    -10.0
#          -47.0             8       5438         10144    312.0     70.0
#          -11.0             4       2563          5072    -29.0    -11.0
#          -6.0              4       2680          5072      1.0      4.0
#          -5.0             12       8257         15412    -24.0    -24.0
# ...                      ...        ...           ...      ...      ...
# Zimbabwe  1891.0         181       2901           664   1986.0   1912.0
#           2209.0         181       2905          5301   2013.0   1851.0
#           3101.0         724      10888         21624  15424.0  13392.0
#           3452.0         362       5444         10262   7570.0   7104.0
#           14237.0        181       2501           511  13587.0  13815.0
#
#                      Y2016    Y2018
# Area     Y2017
# ...

# %%
f.head(40)
# Out:
#                                                    Area Code  Item Code  \
# Element                  Area
# Domestic supply quantity Algeria                         464     311204
#                          Angola                          826     316106
#                          Benin                          6148     310985
#                          Botswana                       2340     313766
#                          Burkina Faso                  27494     316106
#                          Cabo Verde                     4025     308467
#                          Cameroon                       3808     318888
#                          Central African Republic       4292     310780
#                          Chad                           4641     318888
#                          Comoros                         405      24911
#                          Congo                          5474     318888
#                          Côte d'Ivoire                 12733     318888
# ...

# %%
df['Area'].value_counts()
# Out:
# Kenya                          1560
# Egypt                          1488
# Nigeria                        1474
# Côte d'Ivoire                  1467
# Senegal                        1462
# Cameroon                       1460
# Uganda                         1458
# Zambia                         1451
# Malawi                         1447
# Ethiopia                       1447
# Madagascar                     1439
# Mozambique                     1427
# Rwanda                         1426
# Angola                         1424
# United Republic of Tanzania    1419
# Congo                          1413
# Guinea                         1410
# Burkina Faso                   1409
# Niger                          1403
# South Africa                   1399
# Zimbabwe                       1393
# Morocco                        1393
# Mauritius                      1378
# Botswana                       1378
# Ghana                          1354
# Central African Republic       1344
# ...

# %%
f
# Out:
#                                                 Area Code  Item Code  \
# Element                  Area
# Domestic supply quantity Algeria                      464     311204
#                          Angola                       826     316106
#                          Benin                       6148     310985
#                          Botswana                    2340     313766
#                          Burkina Faso               27494     316106
# ...                                                   ...        ...
# Tourist consumption      Cabo Verde                  3150     241236
#                          Egypt                       5546     251428
#                          Kenya                      11172     261986
#                          Mauritius                  12467     243857
#                          Sao Tome and Principe      16019     223107
#
#                                                 Element Code     Y2014  \
# Element                  Area
# ...

# %%
f
# Out:
#                                                 Area Code  Item Code  \
# Element                  Area
# Domestic supply quantity Algeria                      464     311204
#                          Angola                       826     316106
#                          Benin                       6148     310985
#                          Botswana                    2340     313766
#                          Burkina Faso               27494     316106
# ...                                                   ...        ...
# Tourist consumption      Cabo Verde                  3150     241236
#                          Egypt                       5546     251428
#                          Kenya                      11172     261986
#                          Mauritius                  12467     243857
#                          Sao Tome and Principe      16019     223107
#
#                                                 Element Code     Y2014  \
# Element                  Area
# ...

# %%
f[:]
# Out:
#                                                 Area Code  Item Code  \
# Element                  Area
# Domestic supply quantity Algeria                      464     311204
#                          Angola                       826     316106
#                          Benin                       6148     310985
#                          Botswana                    2340     313766
#                          Burkina Faso               27494     316106
# ...                                                   ...        ...
# Tourist consumption      Cabo Verde                  3150     241236
#                          Egypt                       5546     251428
#                          Kenya                      11172     261986
#                          Mauritius                  12467     243857
#                          Sao Tome and Principe      16019     223107
#
#                                                 Element Code     Y2014  \
# Element                  Area
# ...

# %%
f.loc[:, 'Y2015']
# Out:
# Element                   Area
# Domestic supply quantity  Algeria                  85972.86
#                           Angola                   55482.91
#                           Benin                    27661.67
#                           Botswana                  2916.14
#                           Burkina Faso             23658.17
#                                                      ...
# Tourist consumption       Cabo Verde                   5.00
#                           Egypt                      286.00
#                           Kenya                       17.00
#                           Mauritius                   29.00
#                           Sao Tome and Principe       12.00
# Name: Y2015, Length: 803, dtype: float64

# %%
f.loc[:]
# Out:
#                                                 Area Code  Item Code  \
# Element                  Area
# Domestic supply quantity Algeria                      464     311204
#                          Angola                       826     316106
#                          Benin                       6148     310985
#                          Botswana                    2340     313766
#                          Burkina Faso               27494     316106
# ...                                                   ...        ...
# Tourist consumption      Cabo Verde                  3150     241236
#                          Egypt                       5546     251428
#                          Kenya                      11172     261986
#                          Mauritius                  12467     243857
#                          Sao Tome and Principe      16019     223107
#
#                                                 Element Code     Y2014  \
# Element                  Area
# ...
